# %%
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv("data_with_captions_clean.csv")

# %%
data
# Out:
#       Id экзамена  Id вопроса  № вопроса  \
# 0         3373871    30625752          1
# 1         3373871    30625753          2
# 2         3373871    30625754          3
# 3         3373871    30625755          4
# 4         3373872    30625790          1
# ...           ...         ...        ...
# 9793      3448495    32016351          3
# 9794      3448495    32016352          4
# 9795      3448496    32016387          1
# 9796      3448496    32016388          2
# 9797      3448496    32016389          3
#
#                                           Текст вопроса  \
# 0     Добро пожаловать на экзамен! Вопрос устной час...
# 1     Вопрос устной части экзамена. Примите участие ...
# 2     Вопрос устной части экзамена. Начните диалог. ...
# 3     Вопрос устной части экзамена. Опишите картинку...
# 4     Добро пожаловать на экзамен! Вопрос устной час...
# ...                                                 ...
# 9793  Вопрос устной части экзамена. Начните диалог. ...
# ...

# %%
new_data = data.copy()
new_data = new_data.iloc[len(new_data)//2:]

# %%
h_lst = list([i for i in new_data])
h_lst = h_lst[:-1]
new_data = new_data[h_lst]
new_data
# Out:
#       Id экзамена  Id вопроса  № вопроса  \
# 4899      3409254    31272010          4
# 4900      3409255    31272045          1
# 4901      3409255    31272046          2
# 4902      3409255    31272047          3
# 4903      3409255    31272048          4
# ...           ...         ...        ...
# 9793      3448495    32016351          3
# 9794      3448495    32016352          4
# 9795      3448496    32016387          1
# 9796      3448496    32016388          2
# 9797      3448496    32016389          3
#
#                                           Текст вопроса  \
# 4899  Вопрос устной части экзамена. Опишите картинку...
# 4900  Добро пожаловать на экзамен! Вопрос устной час...
# 4901  Вопрос устной части экзамена. Примите участие ...
# 4902  Вопрос устной части экзамена. Начните диалог. ...
# 4903  Вопрос устной части экзамена. Опишите картинку...
# ...                                                 ...
# 9793  Вопрос устной части экзамена. Начните диалог. ...
# ...

# %%
new_data.to_csv("clear_test_with_marks.csv", index=False)
new_data["Оценка экзаменатора"] = None
new_data.to_csv("clear_test.csv", index=False)

# %%
new_data
# Out:
#       Id экзамена  Id вопроса  № вопроса  \
# 4899      3409254    31272010          4
# 4900      3409255    31272045          1
# 4901      3409255    31272046          2
# 4902      3409255    31272047          3
# 4903      3409255    31272048          4
# ...           ...         ...        ...
# 9793      3448495    32016351          3
# 9794      3448495    32016352          4
# 9795      3448496    32016387          1
# 9796      3448496    32016388          2
# 9797      3448496    32016389          3
#
#                                           Текст вопроса  \
# 4899  Вопрос устной части экзамена. Опишите картинку...
# 4900  Добро пожаловать на экзамен! Вопрос устной час...
# 4901  Вопрос устной части экзамена. Примите участие ...
# 4902  Вопрос устной части экзамена. Начните диалог. ...
# 4903  Вопрос устной части экзамена. Опишите картинку...
# ...                                                 ...
# 9793  Вопрос устной части экзамена. Начните диалог. ...
# ...
